# %%
import tensorflow_datasets as tfds
import tensorflow as tf
import matplotlib.pyplot as plt

# %matplotlib
# Out:
# Using matplotlib backend: Qt5Agg

# %%
def plot_graphs(history, string):
    plt.plot(history.history[string])
    plt.plot(history.history['val_'+string])
    plt.xlabel("Epochs")
    plt.ylabel(string)
    plt.legend([string, 'val_'+string])
    plt.show()

# %%
dataset, info = tfds.load('imdb_reviews/subwords8k', with_info=True,
                          as_supervised=True)
train_dataset, test_dataset = dataset['train'], dataset['test']

# The subword tokenizer can be used to tokenize text
tokenizer = info.features['text'].encoder
# Out:
# Dl Completed...: 0 url [00:00, ? url/s]
# Dl Completed...:   0%|          | 0/1 [00:00<?, ? url/s]
# Dl Completed...:   0%|          | 0/1 [00:00<?, ? url/s]
# Dl Size...:   0%|          | 0/80 [00:00<?, ? MiB/s]
# Downloading / extracting dataset imdb_reviews (?? GiB) to /home/jonathan/tensorflow_datasets/imdb_reviews/subwords8k/0.0.1...
# Dl Completed...:   0%|          | 0/1 [00:00<?, ? url/s]B/s]
# Dl Size...:   1%|▏         | 1/80 [00:00<00:59,  1.33 MiB/s]
# Dl Completed...:   0%|          | 0/1 [00:01<?, ? url/s]B/s]
# Dl Size...:   2%|▎         | 2/80 [00:01<00:50,  1.56 MiB/s]
# Dl Completed...:   0%|          | 0/1 [00:01<?, ? url/s]B/s]
# Dl Size...:   4%|▍         | 3/80 [00:01<00:42,  1.82 MiB/s]
# Dl Completed...:   0%|          | 0/1 [00:01<?, ? url/s]B/s]
# Dl Size...:   5%|▌         | 4/80 [00:01<00:35,  2.14 MiB/s]
# Dl Completed...:   0%|          | 0/1 [00:02<?, ? url/s]B/s]
# Dl Size...:   6%|▋         | 5/80 [00:02<00:31,  2.41 MiB/s]
# Dl Completed...:   0%|          | 0/1 [00:02<?, ? url/s]B/s]
# Dl Size...:   8%|▊         | 6/80 [00:02<00:26,  2.75 MiB/s]
# Dl Completed...:   0%|          | 0/1 [00:02<?, ? url/s]B/s]
# Dl Size...:   9%|▉         | 7/80 [00:02<00:24,  3.04 MiB/s]
# Dl Completed...:   0%|          | 0/1 [00:02<?, ? url/s]B/s]
# Dl Size...:  10%|█         | 8/80 [00:02<00:22,  3.15 MiB/s]
# Dl Completed...:   0%|          | 0/1 [00:03<?, ? url/s]B/s]
# Dl Size...:  11%|█▏        | 9/80 [00:03<00:20,  3.40 MiB/s]
# Dl Completed...:   0%|          | 0/1 [00:03<?, ? url/s]iB/s]
# Dl Size...:  12%|█▎        | 10/80 [00:03<00:23,  3.04 MiB/s]
# Dl Completed...:   0%|          | 0/1 [00:03<?, ? url/s]iB/s]
# Dl Size...:  14%|█▍        | 11/80 [00:03<00:21,  3.28 MiB/s]
# Dl Completed...:   0%|          | 0/1 [00:03<?, ? url/s]iB/s]
# Dl Size...:  15%|█▌        | 12/80 [00:03<00:19,  3.43 MiB/s]
# Dl Completed...:   0%|          | 0/1 [00:04<?, ? url/s]iB/s]
# Dl Size...:  16%|█▋        | 13/80 [00:04<00:21,  3.06 MiB/s]
# Dl Completed...:   0%|          | 0/1 [00:04<?, ? url/s]iB/s]
# Dl Size...:  18%|█▊        | 14/80 [00:04<00:20,  3.17 MiB/s]
# Dl Completed...:   0%|          | 0/1 [00:04<?, ? url/s]iB/s]
# Dl Size...:  19%|█▉        | 15/80 [00:04<00:20,  3.23 MiB/s]
# Dl Completed...:   0%|          | 0/1 [00:05<?, ? url/s]iB/s]
# Dl Size...:  20%|██        | 16/80 [00:05<00:21,  2.91 MiB/s]
# Dl Completed...:   0%|          | 0/1 [00:05<?, ? url/s]iB/s]
# Dl Size...:  21%|██▏       | 17/80 [00:05<00:25,  2.48 MiB/s]
# Dl Completed...:   0%|          | 0/1 [00:06<?, ? url/s]iB/s]
# Dl Size...:  22%|██▎       | 18/80 [00:06<00:25,  2.45 MiB/s]
# Dl Completed...:   0%|          | 0/1 [00:06<?, ? url/s]iB/s]
# Dl Size...:  24%|██▍       | 19/80 [00:06<00:22,  2.68 MiB/s]
# Dl Completed...:   0%|          | 0/1 [00:06<?, ? url/s]iB/s]
# Dl Size...:  25%|██▌       | 20/80 [00:06<00:20,  2.92 MiB/s]
# Dl Completed...:   0%|          | 0/1 [00:07<?, ? url/s]iB/s]
# Dl Size...:  26%|██▋       | 21/80 [00:07<00:19,  3.07 MiB/s]
# Dl Completed...:   0%|          | 0/1 [00:07<?, ? url/s]iB/s]
# Dl Size...:  28%|██▊       | 22/80 [00:07<00:21,  2.66 MiB/s]
# Dl Completed...:   0%|          | 0/1 [00:07<?, ? url/s
anaconda3/envs/tf2/lib/python3.7/site-packages/tensorflow_datasets/core/file_format_adapter.py:249: tf_record_iterator (from tensorflow.python.lib.io.tf_record) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use eager execution and:
# `tf.data.TFRecordDataset(path)`
#
# Reading...: 0 examples [00:00, ? examples/s]
# Reading...: 2500 examples [00:00, 285210.39 examples/s]
# Writing...:   0%|          | 0/2500 [00:00<?, ? examples/s]
# Writing...: 100%|██████████| 2500/2500 [00:00<00:00, 196399.33 examples/s]
# Reading...: 0 examples [00:00, ? examples/s]
# Reading...: 2500 examples [00:00, 145552.67 examples/s]
# Writing...:   0%|          | 0/2500 [00:00<?, ? examples/s]
# Writing...: 100%|██████████| 2500/2500 [00:00<00:00, 84504.65 examples/s]
# Reading...: 0 examples [00:00, ? examples/s]
# Reading...: 2500 examples [00:00, 187805.78 examples/s]
# Writing...:   0%|          | 0/2500 [00:00<?, ? examples/s]
# Shuffling...:  30%|███       | 3/10 [00:00<00:00, 24.79 shard/s]xamples/s]
# Reading...: 0 examples [00:00, ? examples/s]
# Reading...: 2500 examples [00:00, 176652.85 examples/s]
# Writing...:   0%|          | 0/2500 [00:00<?, ? examples/s]
# Writing...: 100%|██████████| 2500/2500 [00:00<00:00, 163133.94 examples/s]
# Reading...: 0 examples [00:00, ? examples/s]
# Reading...: 2500 examples [00:00, 160065.95 examples/s]
# Writing...:   0%|          | 0/2500 [00:00<?, ? examples/s]
# Writing...: 100%|██████████| 2500/2500 [00:00<00:00, 146004.62 examples/s]
# Reading...: 0 examples [00:00, ? examples/s]
# Reading...: 2500 examples [00:00, 165706.79 examples/s]
# Writing...:   0%|          | 0/2500 [00:00<?, ? examples/s]
# Shuffling...:  60%|██████    | 6/10 [00:00<00:00, 23.81 shard/s]amples/s]
# Reading...: 0 examples [00:00, ? examples/s]
# Reading...: 2500 examples [00:00, 206591.54 examples/s]
# Writing...:   0%|          | 0/2500 [00:00<?, ? examples/s]
# Writing...: 100%|██████████| 2500/2500 [00:00<00:00, 123940.76 examples/s]
# Reading...: 0 examples [00:00, ? examples/s]
# Reading...: 2500 examples [00:00, 155669.77 examples/s]
# Writing...:   0%|          | 0/2500 [00:00<?, ? examples/s]
# Writing...: 100%|██████████| 2500/2500 [00:00<00:00, 137974.16 examples/s]
# Reading...: 0 examples [00:00, ? examples/s]
# Reading...: 2500 examples [00:00, 167282.36 examples/s]
# Writing...:   0%|          | 0/2500 [00:00<?, ? examples/s]
# Shuffling...:  90%|█████████ | 9/10 [00:00<00:00, 22.98 shard/s]xamples/s]
# Reading...: 0 examples [00:00, ? examples/s]
# Reading...: 2500 examples [00:00, 243730.18 examples/s]
# Writing...:   0%|          | 0/2500 [00:00<?, ? examples/s]
# Shuffling...: 100%|██████████| 10/10 [00:00<00:00, 22.81 shard/s]amples/s]
# 25000 examples [00:23, 1047.76 examples/s]
# Shuffling...:   0%|          | 0/10 [00:00<?, ? shard/s]
# Reading...: 0 examples [00:00, ? examples/s]
# Reading...: 2500 examples [00:00, 322202.56 examples/s]
# Writing...:   0%|          | 0/2500 [00:00<?, ? examples/s]
# Writing...: 100%|██████████| 2500/2500 [00:00<00:00, 94406.77 examples/s]
# Reading...: 0 examples [00:00, ? examples/s]
# Reading...: 2500 examples [00:00, 155319.28 examples/s]
# Writing...:   0%|          | 0/2500 [00:00<?, ? examples/s]
# Writing...: 100%|██████████| 2500/2500 [00:00<00:00, 139668.60 examples/s]
# Reading...: 0 examples [00:00, ? examples/s]
# Reading...: 2500 examples [00:00, 207109.76 examples/s]
# Writing...:   0%|          | 0/2500 [00:00<?, ? examples/s]
# Shuffling...:  30%|███       | 3/10 [00:00<00:00, 24.07 shard/s]xamples/s]
# Reading...: 0 examples [00:00, ? examples/s]
# Reading...: 2500 examples [00:00, 173341.27 examples/s]
# Writing...:   0%|          | 0/2500 [00:00<?, ? examples/s]
# Writing...: 100%|██████████| 2500/2500 [00:00<00:00, 156286.94 examples/s]
# Reading...: 0 examples [00:00, ? examples/s]
# Reading...: 2500 examples [00:00, 202842.88 examples/s]
# Writing...:   0%|          | 0/2500 [00:00<?, ? examples/s]
# Writing...: 100%|██████████| 2500/2500 [00:00<00:00, 231591.32 examples/s]
# Reading...: 0 examples [00:00, ? examples/s]
# Reading...: 2500 examples [00:00, 343356.36 examples/s]
# Writing...:   0%|          | 0/2500 [00:00<?, ? examples/s]
# Writing...: 100%|██████████| 2500/2500 [00:00<00:00, 205518.51 examples/s]
# Reading...: 0 examples [00:00, ? examples/s]
# Reading...: 2500 examples [00:00, 273729.61 examples/s]
# Writing...:   0%|          | 0/2500 [00:00<?, ? examples/s]
# Shuffling...:  70%|███████   | 7/10 [00:00<00:00, 26.40 shard/s]xamples/s]
# Reading...: 0 examples [00:00, ? examples/s]
# Reading...: 2500 examples [00:00, 273465.47 examples/s]
# Writing...:   0%|          | 0/2500 [00:00<?, ? examples/s]
# Writing...: 100%|██████████| 2500/2500 [00:00<00:00, 157626.08 examples/s]
# Reading...: 0 examples [00:00, ? examples/s]
# Reading...: 2500 examples [00:00, 233775.36 examples/s]
# Writing...:   0%|          | 0/2500 [00:00<?, ? examples/s]
# Writing...: 100%|██████████| 2500/2500 [00:00<00:00, 145988.36 examples/s]
# Reading...: 0 examples [00:00, ? examples/s]
# Reading...: 2500 examples [00:00, 213008.31 examples/s]
# Writing...:   0%|          | 0/2500 [00:00<?, ? examples/s]
# Shuffling...: 100%|██████████| 10/10 [00:00<00:00, 26.14 shard/s]amples/s]
# Computing statistics...:   0%|          | 0/2 [00:00<?, ? split/s]
# 0 examples [00:00, ? examples/s]
# 305 examples [00:00, 3048.16 examples/s]
# 967 examples [00:00, 3636.49 examples/s]
# 1582 examples [00:00, 4144.51 examples/s]
# 2122 examples [00:00, 4453.97 examples/s]
# 2698 examples [00:00, 4778.76 examples/s]
# 3349 examples [00:00, 5192.40 examples/s]
# 4017 examples [00:00, 5564.00 examples/s]
# 4610 examples [00:00, 5668.90 examples/s]
# 5184 examples [00:00, 5653.61 examples/s]
# 5788 examples [00:01, 5763.76 examples/s]
# 6457 examples [00:01, 6011.28 examples/s]
# 7148 examples [00:01, 6253.14 examples/s]
# 7780 examples [00:01, 6252.64 examples/s]
# 8410 examples [00:01, 6110.59 examples/s]
# 9073 examples [00:01, 6256.79 examples/s]
# 9738 examples [00:01, 6368.72 examples/s]
# 10446 examples [00:01, 6565.58 examples/s]
# 11107 examples [00:01, 6415.36 examples/s]
# 11752 examples [00:01, 6189.31 examples/s]
# 12375 examples [00:02, 6055.90 examples/s]
# 13026 examples [00:02, 6183.92 examples/s]
# 13722 examples [00:02, 6396.44 examples/s]
# 14397 examples [00:02, 6496.75 examples/s]
# 15087 examples [00:02, 6610.96 examples/s]
# 15811 examples [00:02, 6786.50 examples/s]
# 16493 examples [00:02, 6466.85 examples/s]
# 17145 examples [00:02, 6250.24 examples/s]
# 17776 examples [00:02, 5796.83 examples/s]
# 18379 examples [00:02, 5863.13 examples/s]
# 18973 examples [00:03, 5814.95 examples/s]
# 19644 examples [00:03, 6057.15 examples/s]
# 20326 examples [00:03, 6265.45 examples/s]
# 20961 examples [00:03, 6289.52 examples/s]
# 21676 examples [00:03, 6524.73 examples/s]
# 22375 examples [00:03, 6654.93 examples/s]
# 23045 examples [00:03, 6365.92 examples/s]
# 23688 examples [00:03, 6247.81 examples/s]
# 24409 examples [00:03, 6507.21 examples/s]
# 25000 examples [00:04, 6216.75 examples/s]
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-3-25bf467437b1> in <module>
#       1 dataset, info = tfds.load('imdb_reviews/subwords8k', with_info=True,
# ----> 2                           as_supervised=True)
#       3 train_dataset, test_dataset = dataset['train'], dataset['test']
#       4
#       5 # The subword tokenizer can be used to tokenize text
#
# ~/anaconda3/envs/tf2/lib/python3.7/site-packages/tensorflow_datasets/core/api_utils.py in disallow_positional_args_dec(fn, instance, args, kwargs)
#      50     _check_no_positional(fn, args, ismethod, allowed=allowed)
#      51     _check_required(fn, kwargs)
# ---> 52     return fn(*args, **kwargs)
#      53
#      54   return disallow_positional_args_dec(wrapped)  # pylint: disable=no-value-for-parameter
#
# ~/anaconda3/envs/tf2/lib/python3.7/site-packages/tensorflow_datasets/core/registered.py in load(name, split, data_dir, batch_size, download, as_supervised, with_info, builder_kwargs, download_and_prepare_kwargs, as_dataset_kwargs)
#     251   if download:
#     252     download_and_prepare_kwargs = download_and_prepare_kwargs or {}
# --> 253     dbuilder.download_and_prepare(**download_and_prepare_kwargs)
#     254
#     255   if as_dataset_kwargs is None:
#
# ~/anaconda3/envs/tf2/lib/python3.7/site-packages/tensorflow_datasets/core/api_utils.py in disallow_positional_args_dec(fn, instance, args, kwargs)
#      50     _check_no_positional(fn, args, ismethod, allowed=allowed)
#      51     _check_required(fn, kwargs)
# ---> 52     return fn(*args, **kwargs)
#      53
#      54   return disallow_positional_args_dec(wrapped)  # pylint: disable=no-value-for-parameter
#
# ~/anaconda3/envs/tf2/lib/python3.7/site-packages/tensorflow_datasets/core/dataset_builder.py in download_and_prepare(self, download_dir, download_config)
#     234         else:  # Mode is forced or stats do not exists yet
#     235           logging.info("Computing statistics.")
# --> 236           self.info.compute_dynamic_properties()
#     237         # Set checksums of downloaded (or cached) files, and size:
#     238         self.info.download_checksums = dl_manager.recorded_download_checksums
#
# ~/anaconda3/envs/tf2/lib/python3.7/site-packages/tensorflow_datasets/core/dataset_info.py in compute_dynamic_properties(self)
#     243
#     244   def compute_dynamic_properties(self):
# --> 245     self._compute_dynamic_properties(self._builder)
#     246     self._fully_initialized = True
#     247
#
# ~/anaconda3/envs/tf2/lib/python3.7/site-packages/tensorflow_datasets/core/dataset_info.py in _compute_dynamic_properties(self, builder)
#     256         # Fill DatasetFeatureStatistics.
#     257         dataset_feature_statistics, schema = get_dataset_feature_statistics(
# --> 258             builder, split_name)
#     259
#     260         # Add the statistics to this split.
#
# ~/anaconda3/envs/tf2/lib/python3.7/site-packages/tensorflow_datasets/core/dataset_info.py in get_dataset_feature_statistics(builder, split)
#     488   # Start here, we've processed all examples.
#     489
# --> 490   output_shapes_dict = dataset.output_shapes
#     491   output_types_dict = dataset.output_types
#     492
#
# AttributeError: '_OptionsDataset' object has no attribute 'output_shapes'
